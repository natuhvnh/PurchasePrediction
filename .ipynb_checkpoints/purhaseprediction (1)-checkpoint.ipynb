# %%
from autogluon.tabular import TabularPredictor as task
import numpy as np
import pandas as pd

# %%
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None

# %%
train = pd.read_csv('train.csv')
train
# Out:
#                 csn  article_2m_sum  article_2m_min  article_2m_max  \
# 0      Y2NgaWJoYw==               3               1               2
# 1      Y2NgaWlpYA==              22               5              17
# 2      Y2NgamRpZA==              39               1              16
# 3          Y2NgamVj               3               3               3
# 4      Y2Ngb2FpYg==               1               1               1
# ...             ...             ...             ...             ...
# 38513      amxocWRl              12              12              12
# 38514      amxpa2Rr              61               9              17
# 38515      amxpaWZo              10              10              10
# 38516      amxpamJk              23               2              12
# 38517      amxpbWNk               4               4               4
#
#        salesquantity_2m_sum  salesquantity_2m_min  salesquantity_2m_max  \
# 0                      7.00                  2.00                  5.00
# 1                     33.00                  6.00                 27.00
# 2                     47.86                  2.03                 20.14
# 3                      4.00                  4.00                  4.00
# 4                      0.23                  0.23                  0.23
# ...                     ...                   ...                   ...
# 38513                 17.84                 17.84                 17.84
# 38514                 99.57                 12.03                 32.00
# 38515                 12.93                 12.93                 12.93
# 38516                 26.51                  4.00                 14.34
# 38517                  5.00                  5.00                  5.00
#
#        value_2m_sum  value_2m_min  value_2m_max  ...  salesquantity_1m_sum  \
# 0         161500.00      36500.00     125000.00  ...                  7.00
# 1        2091700.00     668000.00    1423700.00  ...                  6.00
# 2        1476144.00      80917.00     387318.00  ...                 13.29
# 3          33400.00      33400.00      33400.00  ...                  4.00
# 4         132217.00     132217.00     132217.00  ...                  0.23
# ...             ...           ...           ...  ...                   ...
# 38513     282340.00     282340.00     282340.00  ...                  0.00
# 38514    1270664.00     214336.00     357265.00  ...                 41.27
# 38515     477605.00     477605.00     477605.00  ...                  0.00
# 38516     813227.00     195000.00     327044.00  ...                 14.34
# 38517     305400.00     305400.00     305400.00  ...                  0.00
#
#        salesquantity_1m_min  salesquantity_1m_max  value_1m_sum  value_1m_min  \
# 0                      2.00                  5.00     161500.00      36500.00
# 1                      6.00                  6.00     668000.00     668000.00
# 2                      2.03                 11.26     319797.01      80917.00
# 3                      4.00                  4.00      33400.00      33400.00
# 4                      0.23                  0.23     132217.00     132217.00
# ...                     ...                   ...           ...           ...
# 38513                  0.00                  0.00          0.00          0.00
# 38514                 17.00                 24.27     592265.00     235000.00
# 38515                  0.00                  0.00          0.00          0.00
# 38516                 14.34                 14.34     327044.00     327044.00
# 38517                  0.00                  0.00          0.00          0.00
#
#        value_1m_max  days_btw_trans_1m_mean  days_btw_trans_1m_min  \
# 0         125000.00                    2.00                   2.00
# 1         668000.00                   17.00                  17.00
# 2         238880.01                   12.00                  10.00
# 3          33400.00                    0.00                   0.00
# 4         132217.00                    0.00                   0.00
# ...             ...                     ...                    ...
# 38513          0.00                    0.00                   0.00
# 38514     357265.00                   17.50                  14.00
# 38515          0.00                    0.00                   0.00
# 38516     327044.00                   29.00                  29.00
# 38517          0.00                    0.00                   0.00
#
#        days_btw_trans_1m_max  label
# 0                       2.00      N
# 1                      17.00      N
# 2                      14.00      N
# 3                       0.00      N
# 4                       0.00      N
# ...                      ...    ...
# 38513                   0.00      N
# 38514                  21.00      Y
# 38515                   0.00      N
# 38516                  29.00      N
# 38517                   0.00      N
#
# [38518 rows x 27 columns]

# %%
train = train.drop(['csn'], axis=1)
train
# Out:
#        article_2m_sum  article_2m_min  article_2m_max  salesquantity_2m_sum  \
# 0                   3               1               2                  7.00
# 1                  22               5              17                 33.00
# 2                  39               1              16                 47.86
# 3                   3               3               3                  4.00
# 4                   1               1               1                  0.23
# ...               ...             ...             ...                   ...
# 38513              12              12              12                 17.84
# 38514              61               9              17                 99.57
# 38515              10              10              10                 12.93
# 38516              23               2              12                 26.51
# 38517               4               4               4                  5.00
#
#        salesquantity_2m_min  salesquantity_2m_max  value_2m_sum  value_2m_min  \
# 0                      2.00                  5.00     161500.00      36500.00
# 1                      6.00                 27.00    2091700.00     668000.00
# 2                      2.03                 20.14    1476144.00      80917.00
# 3                      4.00                  4.00      33400.00      33400.00
# 4                      0.23                  0.23     132217.00     132217.00
# ...                     ...                   ...           ...           ...
# 38513                 17.84                 17.84     282340.00     282340.00
# 38514                 12.03                 32.00    1270664.00     214336.00
# 38515                 12.93                 12.93     477605.00     477605.00
# 38516                  4.00                 14.34     813227.00     195000.00
# 38517                  5.00                  5.00     305400.00     305400.00
#
#        value_2m_max  days_btw_trans_2m_mean  ...  salesquantity_1m_sum  \
# 0         125000.00                    2.00  ...                  7.00
# 1        1423700.00                   17.00  ...                  6.00
# 2         387318.00                    9.80  ...                 13.29
# 3          33400.00                    0.00  ...                  4.00
# 4         132217.00                    0.00  ...                  0.23
# ...             ...                     ...  ...                   ...
# 38513     282340.00                   11.00  ...                  0.00
# 38514     357265.00                   14.00  ...                 41.27
# 38515     477605.00                    0.00  ...                  0.00
# 38516     327044.00                   19.00  ...                 14.34
# 38517     305400.00                    0.00  ...                  0.00
#
#        salesquantity_1m_min  salesquantity_1m_max  value_1m_sum  value_1m_min  \
# 0                      2.00                  5.00     161500.00      36500.00
# 1                      6.00                  6.00     668000.00     668000.00
# 2                      2.03                 11.26     319797.01      80917.00
# 3                      4.00                  4.00      33400.00      33400.00
# 4                      0.23                  0.23     132217.00     132217.00
# ...                     ...                   ...           ...           ...
# 38513                  0.00                  0.00          0.00          0.00
# 38514                 17.00                 24.27     592265.00     235000.00
# 38515                  0.00                  0.00          0.00          0.00
# 38516                 14.34                 14.34     327044.00     327044.00
# 38517                  0.00                  0.00          0.00          0.00
#
#        value_1m_max  days_btw_trans_1m_mean  days_btw_trans_1m_min  \
# 0         125000.00                    2.00                   2.00
# 1         668000.00                   17.00                  17.00
# 2         238880.01                   12.00                  10.00
# 3          33400.00                    0.00                   0.00
# 4         132217.00                    0.00                   0.00
# ...             ...                     ...                    ...
# 38513          0.00                    0.00                   0.00
# 38514     357265.00                   17.50                  14.00
# 38515          0.00                    0.00                   0.00
# 38516     327044.00                   29.00                  29.00
# 38517          0.00                    0.00                   0.00
#
#        days_btw_trans_1m_max  label
# 0                       2.00      N
# 1                      17.00      N
# 2                      14.00      N
# 3                       0.00      N
# 4                       0.00      N
# ...                      ...    ...
# 38513                   0.00      N
# 38514                  21.00      Y
# 38515                   0.00      N
# 38516                  29.00      N
# 38517                   0.00      N
#
# [38518 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(train, test_size=0.2, random_state=42, shuffle=True)

# %%
train
# Out:
#        article_2m_sum  article_2m_min  article_2m_max  salesquantity_2m_sum  \
# 31944              47               5              17                 39.56
# 20898              71               6              25                 93.17
# 30509              12               2               7                 26.00
# 2322               33               2              13                 52.00
# 1568                4               4               4                  3.46
# ...               ...             ...             ...                   ...
# 6265               58               5              20                121.57
# 11284              41               4              10                261.93
# 38158               3               3               3                  5.00
# 860                48               4              18                144.00
# 15795              30               4               9                 52.26
#
#        salesquantity_2m_min  salesquantity_2m_max  value_2m_sum  value_2m_min  \
# 31944                  2.96                 14.56    2200260.99     190610.00
# 20898                  2.53                 43.85    3701196.99     241644.00
# 30509                  2.00                 21.00     301100.02      25700.00
# 2322                   3.00                 22.00    1354700.00      75900.00
# 1568                   3.46                  3.46      86321.00      86321.00
# ...                     ...                   ...           ...           ...
# 6265                   4.36                 53.29    3086612.92     182968.00
# 11284                 25.60                 48.41    9675729.12     995819.94
# 38158                  5.00                  5.00     546000.00     546000.00
# 860                    7.00                 64.00    3041081.01     203500.00
# 15795                  5.33                 20.00    1402808.00     189900.00
#
#        value_2m_max  days_btw_trans_2m_mean  ...  salesquantity_1m_sum  \
# 31944     987124.00                   14.00  ...                 22.05
# 20898    1230002.00                   12.40  ...                 59.13
# 30509     246500.02                   31.67  ...                 21.00
# 2322      673300.00                   11.50  ...                 32.00
# 1568       86321.00                    0.00  ...                  3.46
# ...             ...                     ...  ...                   ...
# 6265     1006699.01                   14.00  ...                 57.65
# 11284    2053892.93                    1.00  ...                261.93
# 38158     546000.00                    0.00  ...                  5.00
# 860      1380881.01                   16.00  ...                 51.00
# 15795     496367.00                    9.33  ...                 41.33
#
#        salesquantity_1m_min  salesquantity_1m_max  value_1m_sum  value_1m_min  \
# 31944                  3.70                 14.35    1022527.00     247319.00
# 20898                 15.28                 43.85    1807833.99     816235.00
# 30509                 21.00                 21.00     246500.02     246500.02
# 2322                   3.00                 22.00     681400.00      75900.00
# 1568                   3.46                  3.46      86321.00      86321.00
# ...                     ...                   ...           ...           ...
# 6265                   4.36                 53.29     924312.92     182968.00
# 11284                 25.60                 48.41    9675729.12     995819.94
# 38158                  5.00                  5.00     546000.00     546000.00
# 860                    7.00                 44.00     960400.00     203500.00
# 15795                  5.33                 20.00     906441.00     189900.00
#
#        value_1m_max  days_btw_trans_1m_mean  days_btw_trans_1m_min  \
# 31944     521325.00                   11.33                   7.00
# 20898     991598.99                   11.00                   7.00
# 30509     246500.02                   21.00                  21.00
# 2322      329100.00                   11.50                   3.00
# 1568       86321.00                    0.00                   0.00
# ...             ...                     ...                    ...
# 6265      741344.91                   18.00                  16.00
# 11284    2053892.93                    1.00                   1.00
# 38158     546000.00                    0.00                   0.00
# 860       756900.00                   15.00                  14.00
# 15795     359241.00                    9.33                   7.00
#
#        days_btw_trans_1m_max  label
# 31944                  19.00      Y
# 20898                  15.00      Y
# 30509                  21.00      Y
# 2322                   23.00      Y
# 1568                    0.00      N
# ...                      ...    ...
# 6265                   20.00      Y
# 11284                   1.00      Y
# 38158                   0.00      Y
# 860                    16.00      Y
# 15795                  14.00      Y
#
# [30814 rows x 26 columns]

# %%
test
# Out:
#        article_2m_sum  article_2m_min  article_2m_max  salesquantity_2m_sum  \
# 1285                4               4               4                 19.14
# 36462              41              14              27                 89.00
# 6480               38               3              16                 57.99
# 37200              31               3              18                 29.84
# 1278               51               3               9                 61.42
# ...               ...             ...             ...                   ...
# 31711              57               4              14                 89.22
# 35761               5               2               3                  4.69
# 14775              24               5              13                 17.73
# 37513               3               3               3                  4.00
# 35280              21               8              13                 61.97
#
#        salesquantity_2m_min  salesquantity_2m_max  value_2m_sum  value_2m_min  \
# 1285                  19.14                 19.14     481584.02     481584.02
# 36462                 40.00                 49.00    2238800.00     906100.00
# 6480                   3.81                 28.00    2500077.02     173200.00
# 37200                  3.00                 14.84    1445905.99     144900.00
# 1278                   1.30                 12.87    1879166.00      58081.00
# ...                     ...                   ...           ...           ...
# 31711                  3.67                 39.49    3252156.00     101900.00
# 35761                  1.69                  3.00     153332.00      51532.00
# 14775                  3.13                  8.60     568665.00     142200.00
# 37513                  4.00                  4.00     241500.00     241500.00
# 35280                 24.97                 37.00     742933.00     337633.00
#
#        value_2m_max  days_btw_trans_2m_mean  ...  salesquantity_1m_sum  \
# 1285      481584.02                    0.00  ...                 19.14
# 36462    1332700.00                   50.00  ...                 40.00
# 6480      805400.00                    8.80  ...                 29.99
# 37200     709105.99                   16.67  ...                 17.84
# 1278      642586.00                    4.75  ...                 34.11
# ...             ...                     ...  ...                   ...
# 31711     806915.00                   14.67  ...                 71.65
# 35761     101800.00                   25.50  ...                  1.69
# 14775     280588.00                    3.67  ...                  0.00
# 37513     241500.00                    0.00  ...                  0.00
# 35280     405300.00                    9.00  ...                 24.97
#
#        salesquantity_1m_min  salesquantity_1m_max  value_1m_sum  value_1m_min  \
# 1285                  19.14                 19.14     481584.02     481584.02
# 36462                 40.00                 40.00     906100.00     906100.00
# 6480                   3.81                 10.74    1694677.02     173200.00
# 37200                  3.00                 14.84     854005.99     144900.00
# 1278                   4.88                  9.58     789670.99      85849.00
# ...                     ...                   ...           ...           ...
# 31711                  8.78                 39.49    1939936.00     515584.00
# 35761                  1.69                  1.69      51532.00      51532.00
# 14775                  0.00                  0.00          0.00          0.00
# 37513                  0.00                  0.00          0.00          0.00
# 35280                 24.97                 24.97     337633.00     337633.00
#
#        value_1m_max  days_btw_trans_1m_mean  days_btw_trans_1m_min  \
# 1285      481584.02                    0.00                   0.00
# 36462     906100.00                   50.00                  50.00
# 6480      709768.01                    8.80                   2.00
# 37200     709105.99                   10.00                   6.00
# 1278      242196.00                    4.40                   2.00
# ...             ...                     ...                    ...
# 31711     806915.00                    9.00                   5.00
# 35761      51532.00                   20.00                  20.00
# 14775          0.00                    0.00                   0.00
# 37513          0.00                    0.00                   0.00
# 35280     337633.00                    9.00                   9.00
#
#        days_btw_trans_1m_max  label
# 1285                    0.00      N
# 36462                  50.00      Y
# 6480                   26.00      Y
# 37200                  14.00      N
# 1278                    7.00      Y
# ...                      ...    ...
# 31711                  13.00      N
# 35761                  20.00      N
# 14775                   0.00      Y
# 37513                   0.00      N
# 35280                   9.00      Y
#
# [7704 rows x 26 columns]

# %%
task(label='label', path='model').fit(train, auto_stack=True, presets='best_quality')
# task(label='CHURN', path='model').fit(train, num_bag_folds=5, num_bag_sets=1, num_stack_levels=1)
# task(label='label', path='model').fit(train, auto_stack=True)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="model"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "model/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    30814
# Train Data Columns: 25
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['Y', 'N']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = Y, class 0 = N
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Y) vs negative (N) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    63476.04 MB
# 	Train Data (Original)  Memory Usage: 6.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 21 | ['salesquantity_2m_sum', 'salesquantity_2m_min', 'salesquantity_2m_max', 'value_2m_sum', 'value_2m_min', ...]
# 		('int', [])   :  4 | ['article_2m_sum', 'article_2m_min', 'article_2m_max', 'days_left_in_month_2m_last']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 21 | ['salesquantity_2m_sum', 'salesquantity_2m_min', 'salesquantity_2m_max', 'value_2m_sum', 'value_2m_min', ...]
# 		('int', [])   :  4 | ['article_2m_sum', 'article_2m_min', 'article_2m_max', 'days_left_in_month_2m_last']
# 	0.1s = Fit runtime
# 	25 features in original data used to generate 25 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.16 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	0.706	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	28.26s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	0.689	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	28.7s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	0.748	 = Validation accuracy score
# 	5.19s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	0.7488	 = Validation accuracy score
# 	3.69s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ...
# 	0.7286	 = Validation accuracy score
# 	2.16s	 = Training runtime
# 	1.28s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ...
# 	0.7319	 = Validation accuracy score
# 	2.25s	 = Training runtime
# 	1.35s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	0.7467	 = Validation accuracy score
# 	14.12s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ...
# 	0.7316	 = Validation accuracy score
# 	2.06s	 = Training runtime
# 	1.46s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ...
# 	0.7314	 = Validation accuracy score
# 	1.81s	 = Training runtime
# 	1.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# No improvement since epoch 8: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 9: early stopping
# 	0.7498	 = Validation accuracy score
# 	1528.35s	 = Training runtime
# 	0.7s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	0.7494	 = Validation accuracy score
# 	14.09s	 = Training runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	0.748	 = Validation accuracy score
# 	12.37s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.7507	 = Validation accuracy score
# 	13.6s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: KNeighborsUnif_BAG_L2 ...
# 	0.7061	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	26.54s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L2 ...
# 	0.6893	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	25.91s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ...
# 	0.7512	 = Validation accuracy score
# 	4.39s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	0.7509	 = Validation accuracy score
# 	4.67s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ...
# 	0.7497	 = Validation accuracy score
# 	2.63s	 = Training runtime
# 	1.36s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ...
# 	0.7501	 = Validation accuracy score
# 	2.95s	 = Training runtime
# 	1.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	0.7513	 = Validation accuracy score
# 	8.19s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ...
# 	0.7486	 = Validation accuracy score
# 	1.83s	 = Training runtime
# 	1.5s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ...
# 	0.7475	 = Validation accuracy score
# 	2.0s	 = Training runtime
# 	1.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# No improvement since epoch 1: early stopping
# No improvement since epoch 6: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 9: early stopping
# 	0.7512	 = Validation accuracy score
# 	1448.44s	 = Training runtime
# 	0.77s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	0.7517	 = Validation accuracy score
# 	18.6s	 = Training runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	Warning: Exception caused NeuralNetMXNet_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	0.7514	 = Validation accuracy score
# 	11.02s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	0.7532	 = Validation accuracy score
# 	13.18s	 = Training runtime
# 	0.05s	 = Validation runtime
# AutoGluon training complete, total runtime = 3252.18s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("model/")

# %%
y_test = test['label']
test_data = test.drop(['label'], axis=1)
test_data
# Out:
#        article_2m_sum  article_2m_min  article_2m_max  salesquantity_2m_sum  \
# 1285                4               4               4                 19.14
# 36462              41              14              27                 89.00
# 6480               38               3              16                 57.99
# 37200              31               3              18                 29.84
# 1278               51               3               9                 61.42
# ...               ...             ...             ...                   ...
# 31711              57               4              14                 89.22
# 35761               5               2               3                  4.69
# 14775              24               5              13                 17.73
# 37513               3               3               3                  4.00
# 35280              21               8              13                 61.97
#
#        salesquantity_2m_min  salesquantity_2m_max  value_2m_sum  value_2m_min  \
# 1285                  19.14                 19.14     481584.02     481584.02
# 36462                 40.00                 49.00    2238800.00     906100.00
# 6480                   3.81                 28.00    2500077.02     173200.00
# 37200                  3.00                 14.84    1445905.99     144900.00
# 1278                   1.30                 12.87    1879166.00      58081.00
# ...                     ...                   ...           ...           ...
# 31711                  3.67                 39.49    3252156.00     101900.00
# 35761                  1.69                  3.00     153332.00      51532.00
# 14775                  3.13                  8.60     568665.00     142200.00
# 37513                  4.00                  4.00     241500.00     241500.00
# 35280                 24.97                 37.00     742933.00     337633.00
#
#        value_2m_max  days_btw_trans_2m_mean  ...  article_1m_max  \
# 1285      481584.02                    0.00  ...            4.00
# 36462    1332700.00                   50.00  ...           14.00
# 6480      805400.00                    8.80  ...            6.00
# 37200     709105.99                   16.67  ...           18.00
# 1278      642586.00                    4.75  ...            8.00
# ...             ...                     ...  ...             ...
# 31711     806915.00                   14.67  ...           14.00
# 35761     101800.00                   25.50  ...            2.00
# 14775     280588.00                    3.67  ...            0.00
# 37513     241500.00                    0.00  ...            0.00
# 35280     405300.00                    9.00  ...            8.00
#
#        salesquantity_1m_sum  salesquantity_1m_min  salesquantity_1m_max  \
# 1285                  19.14                 19.14                 19.14
# 36462                 40.00                 40.00                 40.00
# 6480                  29.99                  3.81                 10.74
# 37200                 17.84                  3.00                 14.84
# 1278                  34.11                  4.88                  9.58
# ...                     ...                   ...                   ...
# 31711                 71.65                  8.78                 39.49
# 35761                  1.69                  1.69                  1.69
# 14775                  0.00                  0.00                  0.00
# 37513                  0.00                  0.00                  0.00
# 35280                 24.97                 24.97                 24.97
#
#        value_1m_sum  value_1m_min  value_1m_max  days_btw_trans_1m_mean  \
# 1285      481584.02     481584.02     481584.02                    0.00
# 36462     906100.00     906100.00     906100.00                   50.00
# 6480     1694677.02     173200.00     709768.01                    8.80
# 37200     854005.99     144900.00     709105.99                   10.00
# 1278      789670.99      85849.00     242196.00                    4.40
# ...             ...           ...           ...                     ...
# 31711    1939936.00     515584.00     806915.00                    9.00
# 35761      51532.00      51532.00      51532.00                   20.00
# 14775          0.00          0.00          0.00                    0.00
# 37513          0.00          0.00          0.00                    0.00
# 35280     337633.00     337633.00     337633.00                    9.00
#
#        days_btw_trans_1m_min  days_btw_trans_1m_max
# 1285                    0.00                   0.00
# 36462                  50.00                  50.00
# 6480                    2.00                  26.00
# 37200                   6.00                  14.00
# 1278                    2.00                   7.00
# ...                      ...                    ...
# 31711                   5.00                  13.00
# 35761                  20.00                  20.00
# 14775                   0.00                   0.00
# 37513                   0.00                   0.00
# 35280                   9.00                   9.00
#
# [7704 rows x 25 columns]

# %%
predictor = task.load('model')
y_pred = predictor.predict(test_data)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.7538940809968847
# Evaluations on test data:
# {
#     "accuracy": 0.7538940809968847,
#     "balanced_accuracy": 0.754196344897748,
#     "mcc": 0.5130660596011977,
#     "f1": 0.7367397945015275,
#     "precision": 0.795979597959796,
#     "recall": 0.6857069010080125
# }
# Predictions:
#  1285     N
# 36462    N
# 6480     Y
# 37200    Y
# 1278     Y
#         ..
# 31711    Y
# 35761    N
# 14775    N
# 37513    N
# 35280    Y
# Name: label, Length: 7704, dtype: object

# %%
predictor.leaderboard(test, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0         LightGBMXT_BAG_L2        0.76       0.75           18.78
# 1           CatBoost_BAG_L1        0.76       0.75            0.06
# 2            XGBoost_BAG_L1        0.76       0.75            0.87
# 3    NeuralNetFastAI_BAG_L2        0.76       0.75           20.49
# 4           LightGBM_BAG_L1        0.76       0.75            0.04
# 5           CatBoost_BAG_L2        0.76       0.75           18.77
# 6           LightGBM_BAG_L2        0.76       0.75           18.78
# 7      LightGBMLarge_BAG_L2        0.76       0.75           18.84
# 8            XGBoost_BAG_L2        0.76       0.75           19.81
# 9         LightGBMXT_BAG_L1        0.76       0.75            0.06
# 10   NeuralNetFastAI_BAG_L1        0.75       0.75            1.55
# 11     LightGBMLarge_BAG_L1        0.75       0.75            0.11
# 12      WeightedEnsemble_L2        0.75       0.75            2.70
# 13      WeightedEnsemble_L3        0.75       0.75           21.59
# 14  RandomForestEntr_BAG_L2        0.75       0.75           19.15
# 15    ExtraTreesEntr_BAG_L2        0.75       0.75           19.31
# 16    ExtraTreesGini_BAG_L2        0.75       0.75           19.32
# 17  RandomForestGini_BAG_L2        0.75       0.75           19.15
# 18    ExtraTreesEntr_BAG_L1        0.75       0.73            0.62
# 19    ExtraTreesGini_BAG_L1        0.75       0.73            0.65
# 20  RandomForestGini_BAG_L1        0.74       0.73            0.45
# 21  RandomForestEntr_BAG_L1        0.74       0.73            0.49
# 22    KNeighborsUnif_BAG_L1        0.71       0.71            6.96
# 23    KNeighborsUnif_BAG_L2        0.71       0.71           26.07
# 24    KNeighborsDist_BAG_L2        0.69       0.69           25.60
# 25    KNeighborsDist_BAG_L1        0.69       0.69            6.86
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0           63.68   1590.50                     0.06                    0.04
# 1            0.04     14.12                     0.06                    0.04
# 2            0.26     14.09                     0.87                    0.26
# 3           64.40   3034.54                     1.78                    0.77
# 4            0.04      3.69                     0.04                    0.04
# 5           63.69   1594.29                     0.06                    0.05
# 6           63.68   1590.77                     0.06                    0.04
# 7           63.69   1597.13                     0.12                    0.05
# 8           64.04   1604.70                     1.09                    0.40
# 9            0.05      5.19                     0.06                    0.05
# 10           0.70   1528.35                     1.55                    0.70
# 11           0.05     12.37                     0.11                    0.05
# 12           1.18   1591.42                     0.01                    0.05
# 13          68.39   1653.73                     0.01                    0.05
# 14          64.95   1589.05                     0.44                    1.31
# 15          65.10   1588.11                     0.60                    1.46
# 16          65.14   1587.93                     0.60                    1.50
# 17          65.00   1588.73                     0.44                    1.36
# 18           1.46      1.81                     0.62                    1.46
# 19           1.46      2.06                     0.65                    1.46
# 20           1.28      2.16                     0.45                    1.28
# 21           1.35      2.25                     0.49                    1.35
# 22          28.26      0.01                     6.96                   28.26
# 23          90.17   1586.12                     7.35                   26.54
# 24          89.55   1586.11                     6.89                   25.91
# 25          28.70      0.01                     6.86                   28.70
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0                4.39            2       True         16
# 1               14.12            1       True          7
# 2               14.09            1       True         11
# 3             1448.44            2       True         23
# 4                3.69            1       True          4
# 5                8.19            2       True         20
# 6                4.67            2       True         17
# 7               11.02            2       True         25
# 8               18.60            2       True         24
# 9                5.19            1       True          3
# 10            1528.35            1       True         10
# 11              12.37            1       True         12
# 12              13.60            2       True         13
# 13              13.18            3       True         26
# 14               2.95            2       True         19
# 15               2.00            2       True         22
# 16               1.83            2       True         21
# 17               2.63            2       True         18
# 18               1.81            1       True          9
# 19               2.06            1       True          8
# 20               2.16            1       True          5
# 21               2.25            1       True          6
# 22               0.01            1       True          1
# 23               0.01            2       True         14
# 24               0.01            2       True         15
# 25               0.01            1       True          2

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3       0.75          68.39   1653.73                    0.05              13.18            3       True         26
# 1            XGBoost_BAG_L2       0.75          64.04   1604.70                    0.40              18.60            2       True         24
# 2      LightGBMLarge_BAG_L2       0.75          63.69   1597.13                    0.05              11.02            2       True         25
# 3           CatBoost_BAG_L2       0.75          63.69   1594.29                    0.05               8.19            2       True         20
# 4         LightGBMXT_BAG_L2       0.75          63.68   1590.50                    0.04               4.39            2       True         16
# 5    NeuralNetFastAI_BAG_L2       0.75          64.40   3034.54                    0.77            1448.44            2       True         23
# 6           LightGBM_BAG_L2       0.75          63.68   1590.77                    0.04               4.67            2       True         17
# 7       WeightedEnsemble_L2       0.75           1.18   1591.42                    0.05              13.60            2       True         13
# 8   RandomForestEntr_BAG_L2       0.75          64.95   1589.05                    1.31               2.95            2       True         19
# 9    NeuralNetFastAI_BAG_L1       0.75           0.70   1528.35                    0.70            1528.35            1       True         10
# 10  RandomForestGini_BAG_L2       0.75          65.00   1588.73                    1.36               2.63            2       True         18
# 11           XGBoost_BAG_L1       0.75           0.26     14.09                    0.26              14.09            1       True         11
# 12          LightGBM_BAG_L1       0.75           0.04      3.69                    0.04               3.69            1       True          4
# 13    ExtraTreesGini_BAG_L2       0.75          65.14   1587.93                    1.50               1.83            2       True         21
# 14     LightGBMLarge_BAG_L1       0.75           0.05     12.37                    0.05              12.37            1       True         12
# 15        LightGBMXT_BAG_L1       0.75           0.05      5.19                    0.05               5.19            1       True          3
# 16    ExtraTreesEntr_BAG_L2       0.75          65.10   1588.11                    1.46               2.00            2       True         22
# 17          CatBoost_BAG_L1       0.75           0.04     14.12                    0.04              14.12            1       True          7
# 18  RandomForestEntr_BAG_L1       0.73           1.35      2.25                    1.35               2.25            1       True          6
# 19    ExtraTreesGini_BAG_L1       0.73           1.46      2.06                    1.46               2.06            1       True          8
# 20    ExtraTreesEntr_BAG_L1       0.73           1.46      1.81                    1.46               1.81            1       True          9
# 21  RandomForestGini_BAG_L1       0.73           1.28      2.16                    1.28               2.16            1       True          5
# 22    KNeighborsUnif_BAG_L2       0.71          90.17   1586.12                   26.54               0.01            2       True         14
# 23    KNeighborsUnif_BAG_L1       0.71          28.26      0.01                   28.26               0.01            1       True          1
# 24    KNeighborsDist_BAG_L2       0.69          89.55   1586.11                   25.91               0.01            2       True         15
# 25    KNeighborsDist_BAG_L1       0.69          28.70      0.01                   28.70               0.01            1       True          2
# Number of models trained: 26
# Types of models trained:
# {'StackerEnsembleModel_RF', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_NNFastAiTabular', 'WeightedEnsembleModel', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 21 | ['salesquantity_2m_sum', 'salesquantity_2m_min', 'salesquantity_2m_max', 'value_2m_sum', 'value_2m_min', ...]
# ('int', [])   :  4 | ['article_2m_sum', 'article_2m_min', 'article_2m_max', 'days_left_in_month_2m_last']
# *** End of fit() summary ***
# /opt/conda/lib/python3.8/site-packages/autogluon/core/utils/plots.py:140: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'KNeighborsUnif_BAG_L2': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L2': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.7060102550788603,
#   'KNeighborsDist_BAG_L1': 0.6889725449471019,
#   'LightGBMXT_BAG_L1': 0.7479717011747907,
#   'LightGBM_BAG_L1': 0.7487830207048745,
#   'RandomForestGini_BAG_L1': 0.7285973907963913,
#   'RandomForestEntr_BAG_L1': 0.7318751216979296,
#   'CatBoost_BAG_L1': 0.7466735899266567,
#   'ExtraTreesGini_BAG_L1': 0.731550593885896,
#   'ExtraTreesEntr_BAG_L1': 0.7313883299798792,
#   'NeuralNetFastAI_BAG_L1': 0.7497566041409749,
#   'XGBoost_BAG_L1': 0.749399623547738,
#   'LightGBMLarge_BAG_L1': 0.7480041539559941,
#   'WeightedEnsemble_L2': 0.750697734795872,
#   'KNeighborsUnif_BAG_L2': 0.7061076134224703,
#   'KNeighborsDist_BAG_L2': 0.6892970727591354,
#   'LightGBMXT_BAG_L2': 0.751249432076329,
#   'LightGBM_BAG_L2': 0.7508599987018888,
#   'RandomForestGini_BAG_L2': 0.7496916985785682,
#   'RandomForestEntr_BAG_L2': 0.7500811319530084,
#   'CatBoost_BAG_L2': 0.751346790419939,
#   'ExtraTreesGini_BAG_L2': 0.748555851236451,
#   'ExtraTreesEntr_BAG_L2': 0.7475173622379437,
#   'NeuralNetFastAI_BAG_L2': 0.7512169792951255,
#   'XGBoost_BAG_L2': 0.7516713182319725,
#   'LightGBMLarge_BAG_L2': 0.7514116959823457,
#   'WeightedEnsemble_L3': 0.7531965989485299},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'model/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'model/models/KNeighborsDist_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'model/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'model/models/LightGBM_BAG_L1/',
#   'RandomForestGini_BAG_L1': 'model/models/RandomForestGini_BAG_L1/',
#   'RandomForestEntr_BAG_L1': 'model/models/RandomForestEntr_BAG_L1/',
#   'CatBoost_BAG_L1': 'model/models/CatBoost_BAG_L1/',
#   'ExtraTreesGini_BAG_L1': 'model/models/ExtraTreesGini_BAG_L1/',
#   'ExtraTreesEntr_BAG_L1': 'model/models/ExtraTreesEntr_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'model/models/NeuralNetFastAI_BAG_L1/',
#   'XGBoost_BAG_L1': 'model/models/XGBoost_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'model/models/LightGBMLarge_BAG_L1/',
#   'WeightedEnsemble_L2': 'model/models/WeightedEnsemble_L2/',
#   'KNeighborsUnif_BAG_L2': 'model/models/KNeighborsUnif_BAG_L2/',
#   'KNeighborsDist_BAG_L2': 'model/models/KNeighborsDist_BAG_L2/',
#   'LightGBMXT_BAG_L2': 'model/models/LightGBMXT_BAG_L2/',
#   'LightGBM_BAG_L2': 'model/models/LightGBM_BAG_L2/',
#   'RandomForestGini_BAG_L2': 'model/models/RandomForestGini_BAG_L2/',
#   'RandomForestEntr_BAG_L2': 'model/models/RandomForestEntr_BAG_L2/',
#   'CatBoost_BAG_L2': 'model/models/CatBoost_BAG_L2/',
#   'ExtraTreesGini_BAG_L2': 'model/models/ExtraTreesGini_BAG_L2/',
#   'ExtraTreesEntr_BAG_L2': 'model/models/ExtraTreesEntr_BAG_L2/',
#   'NeuralNetFastAI_BAG_L2': 'model/models/NeuralNetFastAI_BAG_L2/',
#   'XGBoost_BAG_L2': 'model/models/XGBoost_BAG_L2/',
#   'LightGBMLarge_BAG_L2': 'model/models/LightGBMLarge_BAG_L2/',
#   'WeightedEnsemble_L3': 'model/models/WeightedEnsemble_L3/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.008165359497070312,
#   'KNeighborsDist_BAG_L1': 0.008555889129638672,
#   'LightGBMXT_BAG_L1': 5.186541318893433,
#   'LightGBM_BAG_L1': 3.6936676502227783,
#   'RandomForestGini_BAG_L1': 2.155738353729248,
#   'RandomForestEntr_BAG_L1': 2.249001979827881,
#   'CatBoost_BAG_L1': 14.119128465652466,
#   'ExtraTreesGini_BAG_L1': 2.058298349380493,
#   'ExtraTreesEntr_BAG_L1': 1.8057749271392822,
#   'NeuralNetFastAI_BAG_L1': 1528.353592634201,
#   'XGBoost_BAG_L1': 14.092077016830444,
#   'LightGBMLarge_BAG_L1': 12.370494365692139,
#   'WeightedEnsemble_L2': 13.601247549057007,
#   'KNeighborsUnif_BAG_L2': 0.014050483703613281,
#   'KNeighborsDist_BAG_L2': 0.011218786239624023,
#   'LightGBMXT_BAG_L2': 4.394655466079712,
#   'LightGBM_BAG_L2': 4.665585994720459,
#   'RandomForestGini_BAG_L2': 2.628863573074341,
#   'RandomForestEntr_BAG_L2': 2.9463798999786377,
#   'CatBoost_BAG_L2': 8.187896490097046,
#   'ExtraTreesGini_BAG_L2': 1.8283970355987549,
#   'ExtraTreesEntr_BAG_L2': 2.004316806793213,
#   'NeuralNetFastAI_BAG_L2': 1448.4395322799683,
#   'XGBoost_BAG_L2': 18.59548783302307,
#   'LightGBMLarge_BAG_L2': 11.024548768997192,
#   'WeightedEnsemble_L3': 13.180623769760132},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 28.260884284973145,
#   'KNeighborsDist_BAG_L1': 28.70047903060913,
#   'LightGBMXT_BAG_L1': 0.04545187950134277,
#   'LightGBM_BAG_L1': 0.03799152374267578,
#   'RandomForestGini_BAG_L1': 1.2827725410461426,
#   'RandomForestEntr_BAG_L1': 1.3455924987792969,
#   'CatBoost_BAG_L1': 0.03977155685424805,
#   'ExtraTreesGini_BAG_L1': 1.4619677066802979,
#   'ExtraTreesEntr_BAG_L1': 1.4567956924438477,
#   'NeuralNetFastAI_BAG_L1': 0.7012228965759277,
#   'XGBoost_BAG_L1': 0.25592780113220215,
#   'LightGBMLarge_BAG_L1': 0.05041217803955078,
#   'WeightedEnsemble_L2': 0.05192923545837402,
#   'KNeighborsUnif_BAG_L2': 26.535165786743164,
#   'KNeighborsDist_BAG_L2': 25.911992073059082,
#   'LightGBMXT_BAG_L2': 0.04133272171020508,
#   'LightGBM_BAG_L2': 0.036978960037231445,
#   'RandomForestGini_BAG_L2': 1.362924575805664,
#   'RandomForestEntr_BAG_L2': 1.3095486164093018,
#   'CatBoost_BAG_L2': 0.04741358757019043,
#   'ExtraTreesGini_BAG_L2': 1.4983253479003906,
#   'ExtraTreesEntr_BAG_L2': 1.4589581489562988,
#   'NeuralNetFastAI_BAG_L2': 0.7655103206634521,
#   'XGBoost_BAG_L2': 0.3963911533355713,
#   'LightGBMLarge_BAG_L2': 0.046280622482299805,
#   'WeightedEnsemble_L3': 0.05250954627990723},
#  'num_bag_folds': 10,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'KNeighborsUnif_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                       model  score_val  pred_time_val  fit_time  \
#  0       WeightedEnsemble_L3       0.75          68.39   1653.73
#  1            XGBoost_BAG_L2       0.75          64.04   1604.70
#  2      LightGBMLarge_BAG_L2       0.75          63.69   1597.13
#  3           CatBoost_BAG_L2       0.75          63.69   1594.29
#  4         LightGBMXT_BAG_L2       0.75          63.68   1590.50
#  5    NeuralNetFastAI_BAG_L2       0.75          64.40   3034.54
#  6           LightGBM_BAG_L2       0.75          63.68   1590.77
#  7       WeightedEnsemble_L2       0.75           1.18   1591.42
#  8   RandomForestEntr_BAG_L2       0.75          64.95   1589.05
#  9    NeuralNetFastAI_BAG_L1       0.75           0.70   1528.35
#  10  RandomForestGini_BAG_L2       0.75          65.00   1588.73
#  11           XGBoost_BAG_L1       0.75           0.26     14.09
#  12          LightGBM_BAG_L1       0.75           0.04      3.69
#  13    ExtraTreesGini_BAG_L2       0.75          65.14   1587.93
#  14     LightGBMLarge_BAG_L1       0.75           0.05     12.37
#  15        LightGBMXT_BAG_L1       0.75           0.05      5.19
#  16    ExtraTreesEntr_BAG_L2       0.75          65.10   1588.11
#  17          CatBoost_BAG_L1       0.75           0.04     14.12
#  18  RandomForestEntr_BAG_L1       0.73           1.35      2.25
#  19    ExtraTreesGini_BAG_L1       0.73           1.46      2.06
#  20    ExtraTreesEntr_BAG_L1       0.73           1.46      1.81
#  21  RandomForestGini_BAG_L1       0.73           1.28      2.16
#  22    KNeighborsUnif_BAG_L2       0.71          90.17   1586.12
#  23    KNeighborsUnif_BAG_L1       0.71          28.26      0.01
#  24    KNeighborsDist_BAG_L2       0.69          89.55   1586.11
#  25    KNeighborsDist_BAG_L1       0.69          28.70      0.01
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                     0.05              13.18            3       True
#  1                     0.40              18.60            2       True
#  2                     0.05              11.02            2       True
#  3                     0.05               8.19            2       True
#  4                     0.04               4.39            2       True
#  5                     0.77            1448.44            2       True
#  6                     0.04               4.67            2       True
#  7                     0.05              13.60            2       True
#  8                     1.31               2.95            2       True
#  9                     0.70            1528.35            1       True
#  10                    1.36               2.63            2       True
#  11                    0.26              14.09            1       True
#  12                    0.04               3.69            1       True
#  13                    1.50               1.83            2       True
#  14                    0.05              12.37            1       True
#  15                    0.05               5.19            1       True
#  16                    1.46               2.00            2       True
#  17                    0.04              14.12            1       True
#  18                    1.35               2.25            1       True
#  19                    1.46               2.06            1       True
#  20                    1.46               1.81            1       True
#  21                    1.28               2.16            1       True
#  22                   26.54               0.01            2       True
#  23                   28.26               0.01            1       True
#  24                   25.91               0.01            2       True
#  25                   28.70               0.01            1       True
#
#      fit_order
#  0          26
#  1          24
#  2          25
#  3          20
#  4          16
#  5          23
#  6          17
#  7          13
#  8          19
#  9          10
#  10         18
#  11         11
#  12          4
#  13         21
#  14         12
#  15          3
#  16         22
#  17          7
#  18          6
#  19          8
#  20          9
#  21          5
#  22         14
#  23          1
#  24         15
#  25          2  }

# %%
predictor.feature_importance(test)
# Out:
# Computing feature importance via permutation shuffling for 25 features using 1000 rows with 3 shuffle sets...
# 	562.44s	= Expected runtime (187.48s per shuffle set)
# 	194.75s	= Actual runtime (Completed 3 of 3 shuffle sets)
#                             importance  stddev  p_value  n  p99_high  p99_low
# days_btw_trans_2m_min             0.01    0.01     0.06  3      0.05    -0.03
# days_btw_trans_1m_mean            0.01    0.01     0.13  3      0.04    -0.03
# article_1m_max                    0.01    0.01     0.12  3      0.04    -0.03
# article_2m_sum                    0.00    0.00     0.13  3      0.03    -0.02
# value_2m_max                      0.00    0.00     0.11  3      0.03    -0.02
# article_1m_sum                    0.00    0.01     0.16  3      0.03    -0.03
# salesquantity_1m_sum              0.00    0.00     0.06  3      0.02    -0.01
# salesquantity_2m_max              0.00    0.01     0.22  3      0.04    -0.03
# days_left_in_month_2m_last        0.00    0.01     0.34  3      0.06    -0.06
# salesquantity_2m_min              0.00    0.00     0.11  3      0.01    -0.01
# article_2m_max                    0.00    0.01     0.32  3      0.04    -0.03
# article_1m_min                    0.00    0.00     0.26  3      0.02    -0.02
# salesquantity_2m_sum              0.00    0.00     0.17  3      0.01    -0.01
# salesquantity_1m_min              0.00    0.00     0.33  3      0.02    -0.02
# days_btw_trans_1m_max             0.00    0.01     0.42  3      0.05    -0.04
# value_2m_min                      0.00    0.00     0.50  3      0.01    -0.01
# value_1m_sum                      0.00    0.01     0.50  3      0.04    -0.04
# article_2m_min                   -0.00    0.00     0.55  3      0.02    -0.02
# value_1m_max                     -0.00    0.00     0.55  3      0.03    -0.03
# days_btw_trans_1m_min            -0.00    0.00     0.62  3      0.02    -0.02
# value_1m_min                     -0.00    0.00     0.80  3      0.02    -0.02
# days_btw_trans_2m_max            -0.00    0.01     0.72  3      0.03    -0.04
# value_2m_sum                     -0.00    0.00     0.89  3      0.01    -0.02
# days_btw_trans_2m_mean           -0.00    0.00     0.89  3      0.02    -0.02
# salesquantity_1m_max             -0.00    0.00     0.88  3      0.02    -0.03

# %%
no_label_data = pd.read_csv('test.csv')
no_label_data
# Out:
#                 csn  article_2m_sum  article_2m_min  article_2m_max  \
# 0      Y2NgaWlpYA==               4               4               4
# 1      Y2NgamRpZA==              57               2              10
# 2      Y2Ngb2FpYg==              24              24              24
# 3          Y2Ngb2Ns              15              15              15
# 4      Y2Ngb2RpaA==              11              11              11
# ...             ...             ...             ...             ...
# 12870      amxnamZl              22              22              22
# 12871      amxoaWFm              30              30              30
# 12872      amxoamNp               2               2               2
# 12873      amxpa2Rr              39              10              17
# 12874      amxpamJk              12              12              12
#
#        salesquantity_2m_sum  salesquantity_2m_min  salesquantity_2m_max  \
# 0                      9.00                  9.00                  9.00
# 1                     82.36                  2.72                 14.85
# 2                     39.45                 39.45                 39.45
# 3                     17.27                 17.27                 17.27
# 4                     62.00                 62.00                 62.00
# ...                     ...                   ...                   ...
# 12870                 42.19                 42.19                 42.19
# 12871                 36.05                 36.05                 36.05
# 12872                  2.00                  2.00                  2.00
# 12873                 66.94                 17.00                 25.67
# 12874                 14.34                 14.34                 14.34
#
#        value_2m_sum  value_2m_min  value_2m_max  ...  article_1m_max  \
# 0         485800.00     485800.00     485800.00  ...            0.00
# 1        3684699.03     157247.00     893297.00  ...           10.00
# 2         619555.00     619555.00     619555.00  ...           24.00
# 3         857401.00     857401.00     857401.00  ...           15.00
# 4         553700.00     553700.00     553700.00  ...           11.00
# ...             ...           ...           ...  ...             ...
# 12870     786510.00     786510.00     786510.00  ...           22.00
# 12871    1622075.00    1622075.00    1622075.00  ...           30.00
# 12872     119000.00     119000.00     119000.00  ...            0.00
# 12873     927838.00     235000.00     357265.00  ...           12.00
# 12874     327044.00     327044.00     327044.00  ...            0.00
#
#        salesquantity_1m_sum  salesquantity_1m_min  salesquantity_1m_max  \
# 0                      0.00                  0.00                  0.00
# 1                     61.58                  4.46                 14.82
# 2                     39.45                 39.45                 39.45
# 3                     17.27                 17.27                 17.27
# 4                     62.00                 62.00                 62.00
# ...                     ...                   ...                   ...
# 12870                 42.19                 42.19                 42.19
# 12871                 36.05                 36.05                 36.05
# 12872                  0.00                  0.00                  0.00
# 12873                 25.67                 25.67                 25.67
# 12874                  0.00                  0.00                  0.00
#
#        value_1m_sum  value_1m_min  value_1m_max  days_btw_trans_1m_mean  \
# 0              0.00          0.00          0.00                    0.00
# 1        2205339.03     175894.00     508311.00                    6.17
# 2         619555.00     619555.00     619555.00                   77.00
# 3         857401.00     857401.00     857401.00                    0.00
# 4         553700.00     553700.00     553700.00                    0.00
# ...             ...           ...           ...                     ...
# 12870     786510.00     786510.00     786510.00                    0.00
# 12871    1622075.00    1622075.00    1622075.00                  113.00
# 12872          0.00          0.00          0.00                    0.00
# 12873     335573.00     335573.00     335573.00                   22.00
# 12874          0.00          0.00          0.00                    0.00
#
#        days_btw_trans_1m_min  days_btw_trans_1m_max
# 0                       0.00                   0.00
# 1                       1.00                  17.00
# 2                      77.00                  77.00
# 3                       0.00                   0.00
# 4                       0.00                   0.00
# ...                      ...                    ...
# 12870                   0.00                   0.00
# 12871                 113.00                 113.00
# 12872                   0.00                   0.00
# 12873                  22.00                  22.00
# 12874                   0.00                   0.00
#
# [12875 rows x 26 columns]

# %%
y_pred = predictor.predict(no_label_data.drop(['csn'], axis=1))
y_pred
# Out:
# 0        N
# 1        Y
# 2        Y
# 3        N
# 4        N
#         ..
# 12870    N
# 12871    N
# 12872    N
# 12873    Y
# 12874    N
# Name: label, Length: 12875, dtype: object

# %%
no_label_data['label'] = y_pred
no_label_data
# Out:
#                 csn  article_2m_sum  article_2m_min  article_2m_max  \
# 0      Y2NgaWlpYA==               4               4               4
# 1      Y2NgamRpZA==              57               2              10
# 2      Y2Ngb2FpYg==              24              24              24
# 3          Y2Ngb2Ns              15              15              15
# 4      Y2Ngb2RpaA==              11              11              11
# ...             ...             ...             ...             ...
# 12870      amxnamZl              22              22              22
# 12871      amxoaWFm              30              30              30
# 12872      amxoamNp               2               2               2
# 12873      amxpa2Rr              39              10              17
# 12874      amxpamJk              12              12              12
#
#        salesquantity_2m_sum  salesquantity_2m_min  salesquantity_2m_max  \
# 0                      9.00                  9.00                  9.00
# 1                     82.36                  2.72                 14.85
# 2                     39.45                 39.45                 39.45
# 3                     17.27                 17.27                 17.27
# 4                     62.00                 62.00                 62.00
# ...                     ...                   ...                   ...
# 12870                 42.19                 42.19                 42.19
# 12871                 36.05                 36.05                 36.05
# 12872                  2.00                  2.00                  2.00
# 12873                 66.94                 17.00                 25.67
# 12874                 14.34                 14.34                 14.34
#
#        value_2m_sum  value_2m_min  value_2m_max  ...  salesquantity_1m_sum  \
# 0         485800.00     485800.00     485800.00  ...                  0.00
# 1        3684699.03     157247.00     893297.00  ...                 61.58
# 2         619555.00     619555.00     619555.00  ...                 39.45
# 3         857401.00     857401.00     857401.00  ...                 17.27
# 4         553700.00     553700.00     553700.00  ...                 62.00
# ...             ...           ...           ...  ...                   ...
# 12870     786510.00     786510.00     786510.00  ...                 42.19
# 12871    1622075.00    1622075.00    1622075.00  ...                 36.05
# 12872     119000.00     119000.00     119000.00  ...                  0.00
# 12873     927838.00     235000.00     357265.00  ...                 25.67
# 12874     327044.00     327044.00     327044.00  ...                  0.00
#
#        salesquantity_1m_min  salesquantity_1m_max  value_1m_sum  value_1m_min  \
# 0                      0.00                  0.00          0.00          0.00
# 1                      4.46                 14.82    2205339.03     175894.00
# 2                     39.45                 39.45     619555.00     619555.00
# 3                     17.27                 17.27     857401.00     857401.00
# 4                     62.00                 62.00     553700.00     553700.00
# ...                     ...                   ...           ...           ...
# 12870                 42.19                 42.19     786510.00     786510.00
# 12871                 36.05                 36.05    1622075.00    1622075.00
# 12872                  0.00                  0.00          0.00          0.00
# 12873                 25.67                 25.67     335573.00     335573.00
# 12874                  0.00                  0.00          0.00          0.00
#
#        value_1m_max  days_btw_trans_1m_mean  days_btw_trans_1m_min  \
# 0              0.00                    0.00                   0.00
# 1         508311.00                    6.17                   1.00
# 2         619555.00                   77.00                  77.00
# 3         857401.00                    0.00                   0.00
# 4         553700.00                    0.00                   0.00
# ...             ...                     ...                    ...
# 12870     786510.00                    0.00                   0.00
# 12871    1622075.00                  113.00                 113.00
# 12872          0.00                    0.00                   0.00
# 12873     335573.00                   22.00                  22.00
# 12874          0.00                    0.00                   0.00
#
#        days_btw_trans_1m_max  label
# 0                       0.00      N
# 1                      17.00      Y
# 2                      77.00      Y
# 3                       0.00      N
# 4                       0.00      N
# ...                      ...    ...
# 12870                   0.00      N
# 12871                 113.00      N
# 12872                   0.00      N
# 12873                  22.00      Y
# 12874                   0.00      N
#
# [12875 rows x 27 columns]

# %%
no_label_data[no_label_data.label == 'Y'].shape[0]
# Out:
# 5652
